# %% [markdown]
# # TOA conversion of provided data

# %% [markdown]
# ## Unzipping zipped folders

# %%
folder_zips = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/"

# %%
# import OS
import os
for x in os.listdir(folder_zips):
    if x.endswith(".zip"):
        # Prints only text file present in My Folder
        print(x)
# Out:
# RAF16APR2025043371009400047SSANSTUC00GTDD_subset1.zip
# R2F17JAN2023060960011000054SSANSTUC00GTDB_subset1.zip
# RAF27JUL2020018870009100055SSANSTUC00GTDD_subset1.zip
# R2F06SEP2021053879009200045SSANSTUC00GTDD_subset1.zip
# R2F30OCT2024070225010600057SSANSTUC00GTDB_subset1.zip
# R2F22AUG2023064038009100052SSANSTUC00GTDA_subset1.zip
# RAF01NOV2020020248009600062SSANSTUC00GTDB_subset1.zip
# R2F29OCT2024070211010100062SSANSTUC00GTDB_subset1.zip
# R2F06JUN2025073330009700059SSANSTUC00GTDA_subset1.zip
# RAF19MAY2021023075010600058SSANSTUC00GTDD_subset1.zip
# RAF18APR2025043393010400065SSANSTUC00GTDD_subset1.zip
# RAF05FEB2025042370010400049SSANSTUC00GTDC.zip
# RegistrionID_output.zip
# R2F11DEC2024070815010000064SSANSTUC00GTDC.zip

# %%
# import OS
import os
for x in os.listdir(folder_zips):
    if x.endswith(".zip"):
        # Prints only text file present in My Folder
        print(x)
        x = os.path.join(folder_zips, x)
        with zipfile.ZipFile(x) as zf:
          # The LISS4 zip files contain a folder with all the data
          # Get the folder name
          foldername = [
              info.filename for info in zf.infolist()
              if info.is_dir()][0]
          # Extract all the data
          zf.extractall()
         
        print(f'Extracted the files to {foldername}.')
# Out:
# RAF16APR2025043371009400047SSANSTUC00GTDD_subset1.zip
# Extracted the files to RAF16APR2025043371009400047SSANSTUC00GTDD_subset1/.
# R2F17JAN2023060960011000054SSANSTUC00GTDB_subset1.zip
# Extracted the files to R2F17JAN2023060960011000054SSANSTUC00GTDB_subset1/.
# RAF27JUL2020018870009100055SSANSTUC00GTDD_subset1.zip
# Extracted the files to RAF27JUL2020018870009100055SSANSTUC00GTDD_subset1/.
# R2F06SEP2021053879009200045SSANSTUC00GTDD_subset1.zip
# Extracted the files to R2F06SEP2021053879009200045SSANSTUC00GTDD_subset1/.
# R2F30OCT2024070225010600057SSANSTUC00GTDB_subset1.zip
# Extracted the files to R2F30OCT2024070225010600057SSANSTUC00GTDB_subset1/.
# R2F22AUG2023064038009100052SSANSTUC00GTDA_subset1.zip
# Extracted the files to R2F22AUG2023064038009100052SSANSTUC00GTDA_subset1/.
# RAF01NOV2020020248009600062SSANSTUC00GTDB_subset1.zip
# Extracted the files to RAF01NOV2020020248009600062SSANSTUC00GTDB_subset1/.
# R2F29OCT2024070211010100062SSANSTUC00GTDB_subset1.zip
# ...

# %%
foldername
# Out:
# 'R2F11DEC2024070815010000064SSANSTUC00GTDC/'

# %%
folder = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/"
import os
for x in os.listdir(folder_zips):
    if not x.endswith(".zip"):
        if not x.endswith(".docx"):
            # Prints only text file present in My Folder
            print(x)
# Out:
# R2F17JAN2023060960011000054SSANSTUC00GTDB_subset1
# RAF27JUL2020018870009100055SSANSTUC00GTDD_subset1
# RAF05FEB2025042370010400049SSANSTUC00GTDC
# RAF18APR2025043393010400065SSANSTUC00GTDD_subset1
# RAF16APR2025043371009400047SSANSTUC00GTDD_subset1
# R2F29OCT2024070211010100062SSANSTUC00GTDB_subset1
# R2F30OCT2024070225010600057SSANSTUC00GTDB_subset1
# R2F22AUG2023064038009100052SSANSTUC00GTDA_subset1
# RegistrionID_output
# R2F06JUN2025073330009700059SSANSTUC00GTDA_subset1
# RAF19MAY2021023075010600058SSANSTUC00GTDD_subset1
# R2F06SEP2021053879009200045SSANSTUC00GTDD_subset1
# RAF01NOV2020020248009600062SSANSTUC00GTDB_subset1
# R2F11DEC2024070815010000064SSANSTUC00GTDC

# %%
folder_list = [r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F17JAN2023060960011000054SSANSTUC00GTDB_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF27JUL2020018870009100055SSANSTUC00GTDD_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF05FEB2025042370010400049SSANSTUC00GTDC",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF18APR2025043393010400065SSANSTUC00GTDD_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF16APR2025043371009400047SSANSTUC00GTDD_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F29OCT2024070211010100062SSANSTUC00GTDB_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F30OCT2024070225010600057SSANSTUC00GTDB_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F22AUG2023064038009100052SSANSTUC00GTDA_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F06JUN2025073330009700059SSANSTUC00GTDA_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF19MAY2021023075010600058SSANSTUC00GTDD_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F06SEP2021053879009200045SSANSTUC00GTDD_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/RAF01NOV2020020248009600062SSANSTUC00GTDB_subset1",
r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/R2F11DEC2024070815010000064SSANSTUC00GTDC"]

# %%
folder = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/"
import os
for x in os.listdir(folder):
    print(x)
# Out:
# RAF07JUN20250_desert
# R2F05JUN2025_desert
# R2F08JUN2025_1_Ocean
# R2F08JUN2025_Ocean

# %%
folder_list = [r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/RAF07JUN20250_desert",
               r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/R2F05JUN2025_desert",
               r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/R2F08JUN2025_1_Ocean",
               r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/R2F08JUN2025_Ocean"
              ]

# %%
import datetime
import ephem
import math
import os
import rioxarray as rxr
import xarray as xr
import zipfile

# %%
from dask.distributed import Client, progress
client = Client()  # set up local cluster on the machine
client
# Out:
# /home/akash/miniconda3/envs/gpu/lib/python3.12/site-packages/distributed/deploy/spec.py:330: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 38567 instead
#   self.scheduler = cls(**self.scheduler_spec.get("options", {}))
# <Client: 'tcp://127.0.0.1:33067' processes=16 threads=128, memory=251.38 GiB>

# %%
def toa_conversion(folder):
    foldername = folder
    
    b2_path = os.path.join(foldername, 'BAND2.tif')
    b3_path = os.path.join(foldername, 'BAND3.tif')
    b4_path = os.path.join(foldername, 'BAND4.tif')
     
    b2_ds = rxr.open_rasterio(b2_path, chunks=True)
    b3_ds = rxr.open_rasterio(b3_path, chunks=True)
    b4_ds = rxr.open_rasterio(b4_path, chunks=True)
    
    metadata_filename = 'BAND_META.txt'
    metadata_filepath = os.path.join(foldername, metadata_filename)
     
    metadata = {}
    with open(metadata_filepath) as f:
      for line in f:
        key, value = line.split('=')
        metadata[key.strip()] = value.strip()
     
    scene_id = metadata['OTSProductID']
    print(f'Metadata extracted successfully for scene: {scene_id}')
    
    scene = xr.concat(
        [b2_ds, b3_ds, b4_ds], dim='band').assign_coords(
        band=['BAND2', 'BAND3', 'BAND4']
    )
     
    scene = scene.where(scene != 0)
    scene.name = scene_id
    # scene
    
    scene = xr.concat(
        [b2_ds, b3_ds, b4_ds], dim='band').assign_coords(
        band=['BAND2', 'BAND3', 'BAND4']
    )
     
    scene = scene.where(scene != 0)
    scene.name = scene_id
    # scene
    
    acq_date_str = metadata['DateOfPass']
    # Date is in the format 04-MAR-2023
    acq_date = datetime.datetime.strptime(
        acq_date_str, '%d-%b-%Y')
     
    sun_elevation_angle = metadata['SunElevationAtCenter']
    sun_zenith_angle = 90 - float(sun_elevation_angle)
    
    observer = ephem.Observer()
    observer.date = acq_date
    sun = ephem.Sun()
    sun.compute(observer)
    d = sun.earth_distance
    
    b2_sr = float(metadata['B2_Lmax'])
    b3_sr = float(metadata['B3_Lmax'])
    b4_sr = float(metadata['B4_Lmax'])
    
    sensor =  metadata['SatID']
    if sensor == 'IRS-R2':
        b2_esun = 185.33
        b3_esun = 157.766
        b4_esun = 111.359
    
    elif sensor == 'IRS-R2A':
        b2_esun = 185.347
        b3_esun = 158.262
        b4_esun = 110.81
    
    pi = math.pi
    sun_zenith_angle_rad = math.radians(sun_zenith_angle)
    
    b2_dn = scene.sel(band='BAND2')
    b3_dn = scene.sel(band='BAND3')
    b4_dn = scene.sel(band='BAND4')
    
    print(b2_sr)
    
    # print(b2_dn)
    b2_rad = b2_dn*b2_sr/1024
    b3_rad = b3_dn*b3_sr/1024
    b4_rad = b4_dn*b4_sr/1024
    
    b2_ref = (pi*b2_rad*d*d)/(b2_esun*math.cos(sun_zenith_angle_rad))
    b3_ref = (pi*b3_rad*d*d)/(b3_esun*math.cos(sun_zenith_angle_rad))
    b4_ref = (pi*b4_rad*d*d)/(b4_esun*math.cos(sun_zenith_angle_rad))
    
    reflectance_bands = [b2_ref, b3_ref, b4_ref]
    scene_ref = xr.concat(
        reflectance_bands, dim='band').assign_coords(
        band=['BAND2', 'BAND3', 'BAND4']
    ).chunk('auto')
    scene_ref.name = scene_id
    
    output_ds = scene_ref.to_dataset('band')
    
    output_file = f'test_{scene_id}.tif'
    
    output_file =os.path.join(foldername, output_file)
    output_options = {
        'driver': 'COG',
        'compress': 'deflate',
        'num_threads': 'all_cpus',
        'windowed': False # set True if you run out of RAM
    }
    #Write the raster.
    
    output_ds[['BAND2', 'BAND3', 'BAND4']].rio.to_raster(
        output_file, **output_options)
    print(f'Output file created {output_file}')

# %%
for folder in folder_list:
    toa_conversion(folder)
# Out:
# Metadata extracted successfully for scene: RAF07JUN2025044104009000054SSANSTUC00GTDB
# 52.0
# Output file created /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/RAF07JUN20250_desert/test_RAF07JUN2025044104009000054SSANSTUC00GTDB.tif
# Metadata extracted successfully for scene: R2F05JUN2025073316009200051SSANSTUC00GTDC
# 52.0
# Output file created /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/R2F05JUN2025_desert/test_R2F05JUN2025073316009200051SSANSTUC00GTDC.tif
# Metadata extracted successfully for scene: R2F08JUN2025073358010700059SSANSTUC00GTDC
# 52.0
# Output file created /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Ocean_desert_training_improve/R2F08JUN2025_1_Ocean/test_R2F08JUN2025073358010700059SSANSTUC00GTDC.tif
# Metadata extracted successfully for scene: R2F08JUN2025073358010700059SSANSTUC00GTDA
# ...

# %% [markdown]
# # Classification of the TAO image to 0: No cloud, 1 : Cloud and 2: Shadow classes

# %% [markdown]
# ## Loading the model

# %% [markdown]
# ## Running on an image and accuracy assessment

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, SubsetRandomSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import joblib
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# --- Device Setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Paths to Saved Components ---
MODEL_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/mlp_model_weights.pth"
SCALER_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/scaler.pkl"
CONFIG_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/model_config.pkl"

# --- Load Saved Scaler and Model Config ---
scaler = joblib.load(SCALER_PATH)
model_config = joblib.load(CONFIG_PATH)

# === Step 1: Load from the newly created combined GeoJSON file ===
file_path = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy/R2F22AUG23_sampled.geojson" ## 6_sept_2021,17_Jan_2023,11_Dec_2024
#to get complete training samples
combined = gpd.read_file(file_path)

# Ensure correct dtype
combined['Id'] = combined['Id'].astype(int)

X = combined[["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]].values.astype(np.float32)
y = combined["Id"].values.astype(np.int64)

# Remove NaNs
not_nan_idx = ~np.isnan(X).any(axis=1)
X, y = X[not_nan_idx], y[not_nan_idx]

# Use loaded scaler to transform data
X_scaled = scaler.transform(X)

# --- Dataset Class ---
class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

dataset = MyDataset(X_scaled, y)

# --- Define the Same MLP Model Architecture ---
class MLP(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes))
    def forward(self, x):
        return self.net(x)

# --- Rebuild and Load Trained Model ---
model = MLP(model_config["input_dim"], model_config["num_classes"]).to(device)
model.load_state_dict(torch.load(MODEL_PATH))
model.eval()

batch_size = 210
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

# --- Evaluate Model ---
y_true, y_pred = [], []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        _, preds = outputs.max(1)
        y_true.extend(y_batch.numpy())
        y_pred.extend(preds.cpu().numpy())

# --- Metrics ---
print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred))

print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_true, y_pred))
# Out:
# Using device: cuda
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     315.0
#            1       0.00      0.00      0.00       0.0
#            2       0.00      0.00      0.00       0.0
#
#     accuracy                           0.00     315.0
#    macro avg       0.00      0.00      0.00     315.0
# weighted avg       0.00      0.00      0.00     315.0
#
#
# === Confusion Matrix ===
# [[  0 210 105]
#  [  0   0   0]
#  [  0   0   0]]
# /home/akash/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %% [markdown]
# ## Using Scikit learn RF

# %%
import joblib
import numpy as np
import geopandas as gpd
from sklearn.metrics import classification_report, confusion_matrix

# === Load the Random Forest Classifier ===
rf_model_path = "/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/rf_final_scikit_classifier.pkl"
clf = joblib.load(rf_model_path)

# === Load the Test GeoJSON Data ===
test_path = "/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy/RAF_18April_25_Sampled.geojson"
gdf = gpd.read_file(test_path)

# Ensure correct dtype
gdf['Id'] = gdf['Id'].astype(int)

# === Extract Features and Labels ===
X = gdf[["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]].values.astype(np.float32)
y = gdf["Id"].values.astype(np.int64)

# === Remove any NaNs ===
valid_mask = ~np.isnan(X).any(axis=1)
X = X[valid_mask]
y = y[valid_mask]

# === Predict using the Random Forest model ===
y_pred = clf.predict(X)

# === Evaluation ===
print("\n=== Classification Report ===")
print(classification_report(y, y_pred))

print("=== Confusion Matrix ===")
print(confusion_matrix(y, y_pred))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.24      0.42      0.31       316
#            1       1.00      0.12      0.21       427
#            2       0.15      0.21      0.18       339
#
#     accuracy                           0.24      1082
#    macro avg       0.46      0.25      0.23      1082
# weighted avg       0.51      0.24      0.23      1082
#
# === Confusion Matrix ===
# [[133   0 183]
#  [156  50 221]
#  [267   0  72]]
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Saving accuracy assessment reports for all the test files:

# %% [markdown]
# ### RF

# %%
import os
import joblib
import numpy as np
import geopandas as gpd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_recall_fscore_support
import pandas as pd

# === Paths ===
rf_model_path = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/rf_final_scikit_classifier.pkl"
geojson_dir = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy"
output_csv_path = os.path.join(geojson_dir, r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy/RF_classification_metrics_report.csv")

# === Load Trained Classifier ===
clf = joblib.load(rf_model_path)

# === Initialize Results List ===
results = []

# === Process Each GeoJSON ===
for file_name in os.listdir(geojson_dir):
    if file_name.endswith(".geojson"):
        file_path = os.path.join(geojson_dir, file_name)
        try:
            gdf = gpd.read_file(file_path)

            if 'Id' not in gdf.columns or any(col not in gdf.columns for col in ['SAMPLE_1', 'SAMPLE_2', 'SAMPLE_3']):
                print(f"Skipping {file_name}: Required columns not found.")
                continue

            gdf['Id'] = gdf['Id'].astype(int)
            X = gdf[["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]].values.astype(np.float32)
            y = gdf["Id"].values.astype(np.int64)

            valid_mask = ~np.isnan(X).any(axis=1)
            X, y = X[valid_mask], y[valid_mask]

            if len(y) == 0:
                print(f"Skipping {file_name}: No valid samples.")
                continue

            y_pred = clf.predict(X)

            accuracy = accuracy_score(y, y_pred)
            precision, recall, f1, _ = precision_recall_fscore_support(y, y_pred, average='weighted', zero_division=0)

            # Append to results
            results.append({
                "Filename": file_name,
                "Samples": len(y),
                "Accuracy": accuracy,
                "Precision": precision,
                "Recall": recall,
                "F1-Score": f1
            })

            print(f"Processed {file_name} - Accuracy: {accuracy:.4f}")

        except Exception as e:
            print(f"Error processing {file_name}: {e}")

# === Save Metrics Summary to CSV ===
df_results = pd.DataFrame(results)
df_results.to_csv(output_csv_path, index=False)
print(f"\n✅ Classification summary saved to: {output_csv_path}")
# Out:
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /home/akash/.local/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ### MLP

# %%
import os
import torch
import torch.nn as nn
import joblib
import numpy as np
import geopandas as gpd
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report, accuracy_score, precision_recall_fscore_support

# --- Device Setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Paths ---
MODEL_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/mlp_model_weights.pth"
SCALER_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/scaler.pkl"
CONFIG_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/model_config.pkl"
GEOJSON_DIR = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy"
OUTPUT_CSV = os.path.join(GEOJSON_DIR, r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy/mlp_classification_metrics_report.csv")

# --- Load scaler and model config ---
scaler = joblib.load(SCALER_PATH)
model_config = joblib.load(CONFIG_PATH)

# --- Define Dataset ---
class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# --- Define Model ---
class MLP(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# --- Load Model ---
model = MLP(model_config["input_dim"], model_config["num_classes"]).to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

# --- Store Results ---
results = []

# --- Iterate Over GeoJSON Files ---
for file_name in os.listdir(GEOJSON_DIR):
    if file_name.endswith(".geojson"):
        file_path = os.path.join(GEOJSON_DIR, file_name)
        try:
            gdf = gpd.read_file(file_path)

            # Check required columns
            if 'Id' not in gdf.columns or not all(col in gdf.columns for col in ["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]):
                print(f"Skipping {file_name}: Required columns missing.")
                continue

            # Prepare features
            gdf['Id'] = gdf['Id'].astype(int)
            X = gdf[["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]].values.astype(np.float32)
            y = gdf["Id"].values.astype(np.int64)

            # Remove NaNs
            mask = ~np.isnan(X).any(axis=1)
            X, y = X[mask], y[mask]

            if len(y) == 0:
                print(f"Skipping {file_name}: No valid samples.")
                continue

            # Scale
            X_scaled = scaler.transform(X)

            # Create dataset and dataloader
            dataset = MyDataset(X_scaled, y)
            loader = DataLoader(dataset, batch_size=256, shuffle=False)

            # Predict
            y_true, y_pred = [], []
            with torch.no_grad():
                for X_batch, y_batch in loader:
                    X_batch = X_batch.to(device)
                    outputs = model(X_batch)
                    _, preds = outputs.max(1)
                    y_true.extend(y_batch.numpy())
                    y_pred.extend(preds.cpu().numpy())

            # Metrics
            acc = accuracy_score(y_true, y_pred)
            precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)

            results.append({
                "Filename": file_name,
                "Samples": len(y_true),
                "Accuracy": acc,
                "Precision": precision,
                "Recall": recall,
                "F1-Score": f1
            })

            print(f"Processed {file_name}: Accuracy = {acc:.4f}")

        except Exception as e:
            print(f"Error processing {file_name}: {e}")

# --- Save to CSV ---
results_df = pd.DataFrame(results)
results_df.to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ All reports saved to: {OUTPUT_CSV}")
# Out:
# Using device: cuda
# Processed RAF_5Feb_25_Sampled.geojson: Accuracy = 0.8445
# Processed RAF19MAY21_Sampled.geojson: Accuracy = 0.8953
# Processed RAF_18April_25_Sampled.geojson: Accuracy = 0.2505
# Processed R2F_30Oct_24_Sampled.geojson: Accuracy = 0.8888
# Processed 6_sept_2021.geojson: Accuracy = 0.7561
# Processed 11_Dec_2024.geojson: Accuracy = 0.8067
# Processed R2F22AUG23_sampled.geojson: Accuracy = 0.0000
# Processed RAF27JUL20_Sampled.geojson: Accuracy = 0.8237
# Processed 17_Jan_2023.geojson: Accuracy = 0.9168
# Processed RAF_01Nov_20_Sampled.geojson: Accuracy = 0.5244
# Processed RAF_16April_25_Sampled.geojson: Accuracy = 0.7989
# Processed R2F29OCT24_Sampled.geojson: Accuracy = 0.5984
# Processed 6_june_2025.geojson: Accuracy = 0.7156
#
# ✅ All reports saved to: /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy/mlp_classification_metrics_report.csv

# %% [markdown]
# ## Combined accuracy metrics for the test dataset

# %%
import os
import torch
import torch.nn as nn
import joblib
import numpy as np
import geopandas as gpd
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, precision_recall_fscore_support

# --- Device Setup ---
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# --- Paths ---
MODEL_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/mlp_model_weights.pth"
SCALER_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/scaler.pkl"
CONFIG_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/model_config.pkl"
GEOJSON_DIR = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Final_samples_for_test_accuracy"

# --- Load scaler and model config ---
scaler = joblib.load(SCALER_PATH)
model_config = joblib.load(CONFIG_PATH)

# --- Define Dataset ---
class MyDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)
    def __len__(self):
        return len(self.y)
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# --- Define Model ---
class MLP(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# --- Load Model ---
model = MLP(model_config["input_dim"], model_config["num_classes"]).to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

# --- Combine All GeoJSONs ---
all_data = []
for file_name in os.listdir(GEOJSON_DIR):
    if file_name.endswith(".geojson"):
        file_path = os.path.join(GEOJSON_DIR, file_name)
        try:
            gdf = gpd.read_file(file_path)
            if 'Id' not in gdf.columns or not all(col in gdf.columns for col in ["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]):
                print(f"Skipping {file_name}: Required columns missing.")
                continue
            gdf['Id'] = gdf['Id'].astype(int)
            all_data.append(gdf)
        except Exception as e:
            print(f"Error reading {file_name}: {e}")

if not all_data:
    print("No valid data found.")
    exit()

# --- Combine into a single GeoDataFrame ---
combined_gdf = gpd.GeoDataFrame(pd.concat(all_data, ignore_index=True))

# --- Drop NaNs and extract features/labels ---
X = combined_gdf[["SAMPLE_1", "SAMPLE_2", "SAMPLE_3"]].values.astype(np.float32)
y = combined_gdf["Id"].values.astype(np.int64)

mask = ~np.isnan(X).any(axis=1)
X, y = X[mask], y[mask]

# --- Scale Features ---
X_scaled = scaler.transform(X)

# --- Dataset and Dataloader ---
dataset = MyDataset(X_scaled, y)
loader = DataLoader(dataset, batch_size=256, shuffle=False)

# --- Predict and Evaluate ---
y_true, y_pred = [], []

with torch.no_grad():
    for X_batch, y_batch in loader:
        X_batch = X_batch.to(device)
        outputs = model(X_batch)
        _, preds = outputs.max(1)
        y_true.extend(y_batch.numpy())
        y_pred.extend(preds.cpu().numpy())

# --- Metrics ---
acc = accuracy_score(y_true, y_pred)
precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='weighted', zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# --- Print Report ---
print("\n=== Combined Test Set Report ===")
print(f"Total Samples: {len(y_true)}")
print(f"Accuracy: {acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")

print("\n=== Confusion Matrix ===")
print(cm)

print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, digits=4))
# Out:
# Using device: cuda
#
# === Combined Test Set Report ===
# Total Samples: 15568
# Accuracy: 0.7328
# Precision: 0.7496
# Recall: 0.7328
# F1-Score: 0.7359
#
# === Confusion Matrix ===
# [[3493  396 1384]
#  [ 984 4096  487]
#  [ 908    0 3820]]
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0     0.6487    0.6624    0.6555      5273
#            1     0.9118    0.7358    0.8144      5567
#            2     0.6712    0.8080    0.7333      4728
#
#     accuracy                         0.7328     15568
#    macro avg     0.7439    0.7354    0.7344     15568
# weighted avg     0.7496    0.7328    0.7359     15568

# %% [markdown]
# ## Classifying the images with the final model and saving them :

# %%
import os
import torch
import torch.nn as nn
import joblib
import numpy as np
import rasterio
from torch.utils.data import DataLoader
from tqdm import tqdm

# Paths
MODEL_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/mlp_model_weights.pth"
SCALER_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/scaler.pkl"
CONFIG_PATH = r"/home/akash/NRSC_hackathon/Samples_extracted/trained_models/final_model/model_config.pkl"
RASTER_DIR = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/test_scenes"
OUTPUT_DIR = r"/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Classification_outputs_for_test_data"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('Device in use: ', device)

# Load scaler and model config
scaler = joblib.load(SCALER_PATH)
model_config = joblib.load(CONFIG_PATH)

# Define the MLP model
class MLP(nn.Module):
    def __init__(self, input_dim, num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, num_classes)
        )
    def forward(self, x):
        return self.net(x)

# Load model
model = MLP(model_config["input_dim"], model_config["num_classes"]).to(device)
model.load_state_dict(torch.load(MODEL_PATH, map_location=device))
model.eval()

# Process each scene folder
scene_folders = [f for f in os.listdir(RASTER_DIR) if os.path.isdir(os.path.join(RASTER_DIR, f))]

for scene in tqdm(scene_folders, desc="Processing Scenes"):
    folder_path = os.path.join(RASTER_DIR, scene)
    
    # Look for a tif file starting with "test_"
    tif_files = [f for f in os.listdir(folder_path) if f.startswith("test_") and f.endswith(".tif")]
    if not tif_files:
        print(f"❌ No test_*.tif found in {scene}")
        continue
    
    tif_path = os.path.join(folder_path, tif_files[0])  # Use first match

    try:
        with rasterio.open(tif_path) as src:
            img = src.read([1, 2, 3]).astype(np.float32)
            height, width = img.shape[1], img.shape[2]
            profile = src.profile

        flat_pixels = img.reshape(3, -1).T
        valid_mask = ~np.isnan(flat_pixels).any(axis=1)
        valid_pixels = flat_pixels[valid_mask]
        scaled_pixels = scaler.transform(valid_pixels)

        batch_size = 1024
        predictions = []
        with torch.no_grad():
            for i in range(0, len(scaled_pixels), batch_size):
                batch = torch.tensor(scaled_pixels[i:i+batch_size], dtype=torch.float32).to(device)
                outputs = model(batch)
                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                predictions.append(preds)

        predicted_classes = np.full(flat_pixels.shape[0], fill_value=255, dtype=np.uint8)
        predicted_classes[valid_mask] = np.concatenate(predictions)
        classified_img = predicted_classes.reshape(height, width)

        # Save the classified raster with the scene folder name
        output_path = os.path.join(OUTPUT_DIR, f"{scene}.tif")
        profile.update(dtype=rasterio.uint8, count=1, nodata=255)
        with rasterio.open(output_path, 'w', **profile) as dst:
            dst.write(classified_img, 1)

    except Exception as e:
        print(f"❌ Error processing {scene}: {e}")

print(f"\n✅ All classified outputs saved to: {OUTPUT_DIR}")
# Out:
# Device in use:  cuda
# Processing Scenes: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 13/13 [03:12<00:00, 14.78s/it]
# ✅ All classified outputs saved to: /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Classification_outputs_for_test_data

# %% [markdown]
# ## conversion to shapefiles from tif masks

# %%
import os
import geopandas as gpd
import rasterio
from rasterio.features import shapes
from shapely.geometry import shape
import numpy as np
from tqdm import tqdm

# === Paths ===
RASTER_DIR = "/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Classification_outputs_for_test_data"
OUTPUT_SHP_DIR = "/home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Vectorized_classified_outputs"

os.makedirs(OUTPUT_SHP_DIR, exist_ok=True)

# === Process Each Raster ===
for file in tqdm(os.listdir(RASTER_DIR), desc="Vectorizing Rasters"):
    if file.endswith(".tif"):
        raster_path = os.path.join(RASTER_DIR, file)
        shp_output_path = os.path.join(OUTPUT_SHP_DIR, file.replace(".tif", ".shp"))

        with rasterio.open(raster_path) as src:
            image = src.read(1)  # Read single band
            mask = image != src.nodata  # Exclude NoData (255)

            results = (
                {"properties": {"Id": int(v)}, "geometry": s}
                for s, v in shapes(image, mask=mask, transform=src.transform)
            )

            geoms = list(results)

            if not geoms:
                print(f"⚠️ No valid shapes found in {file}")
                continue

            gdf = gpd.GeoDataFrame.from_features(geoms, crs=src.crs)

            # Optional: simplify or clean small polygons here

            gdf.to_file(shp_output_path)
            print(f"✅ Saved shapefile: {shp_output_path}")

print("\n✅ All rasters vectorized to shapefiles.")
# Out:
# Vectorizing Rasters:  14%|██████████████████████                                                                                                                                    | 2/14 [00:01<00:09,  1.28it/s]
# ✅ Saved shapefile: /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Vectorized_classified_outputs/RAF19MAY2021023075010600058SSANSTUC00GTDD_subset1.shp
# Vectorizing Rasters:  21%|█████████████████████████████████                                                                                                                         | 3/14 [03:25<15:41, 85.63s/it]
# ✅ Saved shapefile: /home/akash/NRSC_hackathon/NRSC_Final_Test_Data_for_submission/TestData-Cloud-Shadow/Vectorized_classified_outputs/RAF18APR2025043393010400065SSANSTUC00GTDD_subset1.shp
# ...

# %%
import torch

# Check if CUDA is available
print("CUDA available:", torch.cuda.is_available())

# Number of GPUs
print("Number of GPUs:", torch.cuda.device_count())
# Out:
# CUDA available: True
# Number of GPUs: 1
